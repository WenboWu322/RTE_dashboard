# %%
import pandas as pd


# 读取CSV文件，指定分隔符为分号
file_path = 'raw_data/monitoring_PSEM_brute.csv'
df = pd.read_csv(file_path, sep=';')


# 筛选csemCur为5000270722的数据
filtered_df = df[df['csemCur'] == 5000270722]

filtered_df
 







# # 查看数据的前几行
# filtered_df.head(50)
# Out:
#                   dateMeasure           temperature  \
# 5045925  2022-08-15T13:58:52Z  27,30999946594238281
# 5045940  2022-08-15T16:58:51Z  27,54000091552734375
# 5045963  2022-08-15T15:58:51Z  27,10000038146972656
# 5045996  2022-08-15T19:58:50Z  24,10000038146972656
# 5046022  2022-08-15T21:58:50Z  20,77000045776367188
# ...                       ...                   ...
# 5239790  2023-01-12T03:46:24Z   1,47000002861022949
# 5239805  2023-01-12T08:46:24Z   4,46000003814697266
# 5239812  2023-01-12T07:46:24Z   4,03000020980834961
# 5239838  2023-01-12T10:48:41Z   9,88000011444091797
# 5239847  2023-01-12T11:46:23Z  10,19999980926513672
#
#         compensatedRelativePressure             pressure     csemCur  \
# 5045925         3,46000003814697266  4,59999990463256836  5000270722
# 5045940         3,45000004768371582  4,59000015258789062  5000270722
# 5045963         3,45000004768371582  4,59000015258789062  5000270722
# ...
